# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pywt
import itertools
import nolds

import warnings
warnings.filterwarnings("ignore")

import gc
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dense, LSTM, GRU, SimpleRNN, Conv1D,
                                     MaxPooling1D, Flatten, Input, Reshape,
                                     Lambda, concatenate, TimeDistributed)
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import (mean_squared_error, mean_absolute_error, 
                             r2_score, explained_variance_score)
from sklearn.model_selection import TimeSeriesSplit, ParameterGrid
from statsmodels.tsa.arima.model import ARIMA
from arch import arch_model

# ------------------------------------------------
# 0. Setup plot directory
# ------------------------------------------------
os.makedirs('plots', exist_ok=True)

# ------------------------------------------------
# Parameter grids for hyperparameter search
# ------------------------------------------------
param_grid = {
    'ANN': {
        'layers': [[128,64,32], [64,32]],
        'learning_rate': [1e-3, 1e-4],
        'batch_size': [32, 64]
    },
    # extend for other models if needed
}

# ------------------------------------------------
# 1. Load Data
# ------------------------------------------------
def load_data(path):
    df = pd.read_csv(path, parse_dates=['DATE'])
    df.columns = df.columns.str.upper()
    df.set_index('DATE', inplace=True)
    return df

# ------------------------------------------------
# 2. Data regimes labeling
# ------------------------------------------------
market_periods = {
    'bull': ('2012-10-05','2018-01-01'),
    'bear': ('2018-01-02','2020-03-16'),
    'recovery': ('2020-03-17','2025-03-27')
}

def label_market_regime(date):
    # Handle different date types
    if isinstance(date, (int, float)):
        # Convert timestamp to datetime
        date = pd.to_datetime(date, unit='ns' if date > 1e15 else 's')
    elif not hasattr(date, 'strftime'):
        # Convert to datetime if it's not already
        date = pd.to_datetime(date)
    
    ds = date.strftime('%Y-%m-%d')
    for regime,(start,end) in market_periods.items():
        if start <= ds <= end:
            return regime
    return 'other'

# ------------------------------------------------
# 3. Fractal Filters
# ------------------------------------------------
def hurst_exponent(ts):
    lags = range(2, 20)
    tau = [np.std(ts[lag:] - ts[:-lag]) for lag in lags if lag < len(ts)]
    if len(tau) < 2:
        return np.nan
    poly = np.polyfit(np.log(range(2, 2+len(tau))), np.log(tau), 1)
    return poly[0]

def apply_hurst(df, price_col='PRICE', window_size=100):
    df['HURST_PRICE'] = df[price_col].rolling(window=window_size).apply(hurst_exponent, raw=True)
    return df

# ------------------------------------------------
# 4. Wavelet Filters
# ------------------------------------------------
def apply_wavelet_energy(segment, wavelet='db4', level=3):
    coeffs = pywt.wavedec(segment, wavelet, level=level)
    return [np.sum(c**2) for c in coeffs]

def apply_wavelets(df, col_list=None, window=150):
    if col_list is None:
        col_list = ['PRICE', 'PUTCALLRATIO']
    wavelet_cols = []
    for col in col_list:
        feats = []
        for i in range(window, len(df)):
            segment = df[col].iloc[i-window:i]
            feats.append(apply_wavelet_energy(segment) if not segment.isnull().any() else [np.nan]*4)
        for j in range(4):
            new_col = f'WAVELET_{col}_L{j}'
            df[new_col] = [np.nan]*window + [x[j] for x in feats]
            wavelet_cols.append(new_col)
    return df, wavelet_cols

# ------------------------------------------------
# 5. Feature Preparation
# ------------------------------------------------
def prepare_features(df, features, target='VIX', lookback=10, scale_method='MinMax'):
    df_clean = df.dropna(subset=features+[target]).copy()
    df_clean['regime'] = df_clean.index.to_series().apply(label_market_regime)
    if len(df_clean) <= lookback:
        return None, None, None, None
    scaler = StandardScaler() if scale_method=='Standard' else MinMaxScaler()
    scaled = scaler.fit_transform(df_clean[features + [target]])
    X, y, idx = [], [], []
    for i in range(lookback, len(scaled)):
        X.append(scaled[i-lookback:i, :-1])
        y.append(scaled[i, -1])
        idx.append(df_clean.index[i])
    return np.array(X), np.array(y), idx, scaler

# ------------------------------------------------
# 6. Statistical Baselines: ARIMA & GARCH
# ------------------------------------------------
def train_arima_baseline(y_series, p=1, d=0, q=1):
    model = ARIMA(y_series, order=(p,d,q))
    return model.fit()

def train_garch_baseline(y_series, p=1, q=1):
    model = arch_model(y_series, vol='Garch', p=p, q=q, dist='normal')
    return model.fit(disp='off')

# ------------------------------------------------
# 7. Model Builders
# ------------------------------------------------
def squash(vectors, axis=-1):
    s2n = tf.reduce_sum(tf.square(vectors), axis, keepdims=True)
    scale = s2n / (1 + s2n) / tf.sqrt(s2n + K.epsilon())
    return scale * vectors

def build_capsule_model(input_shape, num_capsule=10, dim_capsule=16):
    inputs = Input(shape=input_shape)
    x = Conv1D(128,3,activation='relu',padding='same')(inputs)
    x = MaxPooling1D(2)(x)
    x = Conv1D(256,3,activation='relu',padding='same')(x)
    x = MaxPooling1D(2)(x)
    x = Flatten()(x)
    x = Reshape((-1,dim_capsule))(x)
    x = Lambda(squash)(x)
    caps = [Lambda(squash)(TimeDistributed(Dense(dim_capsule))(x)) for _ in range(num_capsule)]
    net = concatenate(caps,axis=-1)
    net = Flatten()(net)
    net = Dense(64,activation='relu')(net)
    net = Dense(32,activation='relu')(net)
    out = Dense(1)(net)
    model = Model(inputs, out)
    model.compile(optimizer=Adam(), loss='mse')
    return model

def build_model(model_type, input_shape, layers=None, lr=1e-3):
    if model_type=='CapsNet':
        return build_capsule_model(input_shape)
    model = Sequential()
    if layers is None:
        # default layers per type
        configs = {
            'ANN': [128,64,32],
            'RNN': None, 'LSTM': None, 'GRU': None,
            'CNN': None, 'CNN_LSTM': None
        }
        layers = configs.get(model_type)
    if model_type=='ANN':
        model.add(Input(shape=input_shape)); model.add(Flatten())
        for units in layers: model.add(Dense(units,activation='relu'))
        model.add(Dense(1))
    elif model_type in ['RNN','LSTM','GRU']:
        LayerClass = {'RNN': SimpleRNN,'LSTM':LSTM,'GRU':GRU}[model_type]
        model.add(LayerClass(128,return_sequences=True,input_shape=input_shape))
        model.add(LayerClass(64))
        model.add(Dense(1))
    elif model_type=='CNN':
        model.add(Conv1D(128,3,activation='relu',input_shape=input_shape))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(64,3,activation='relu'))
        model.add(MaxPooling1D(2)); model.add(Flatten())
        model.add(Dense(1))
    elif model_type=='CNN_LSTM':
        model.add(Conv1D(64,3,activation='relu',input_shape=input_shape))
        model.add(MaxPooling1D(2))
        model.add(LSTM(128,return_sequences=True)); model.add(LSTM(64))
        model.add(Dense(1))
    optimizer = Adam(learning_rate=lr)
    model.compile(optimizer=optimizer, loss='mse')
    return model

# ------------------------------------------------
# 8. Metrics & DM Test
# ------------------------------------------------
def calculate_metrics(y_true,y_pred):
    return {
        'mse': mean_squared_error(y_true,y_pred),
        'rmse': np.sqrt(mean_squared_error(y_true,y_pred)),
        'mae': mean_absolute_error(y_true,y_pred),
        'r2': r2_score(y_true,y_pred),
        'explained_variance': explained_variance_score(y_true,y_pred),
        'mape': np.mean(np.abs((y_true-y_pred)/(y_true+1e-8)))*100
    }
def diebold_mariano_test(y_true,y_pred1,y_pred2,crit='MSE'):
    e1,e2=y_true-y_pred1,y_true-y_pred2
    d=(e1**2)-(e2**2);DM=d.mean()/np.sqrt(d.var(ddof=1)/len(d))
    p=2*(1-0.5*(1+tf.math.erf(abs(DM)/tf.sqrt(2.0))))
    return DM,p

def compare_models_dm(pred_df, group_by_cols):
    """Compare models using Diebold-Mariano test within each group"""
    dm_results = []
    
    # Group by the specified columns
    for group_vals, group_data in pred_df.groupby(group_by_cols):
        models = group_data['model'].unique()
        
        # Compare each pair of models
        for i, model1 in enumerate(models):
            for model2 in models[i+1:]:
                data1 = group_data[group_data['model'] == model1]
                data2 = group_data[group_data['model'] == model2]
                
                # Ensure same time indices
                common_idx = set(data1['time_index']).intersection(set(data2['time_index']))
                if len(common_idx) < 2:
                    continue
                    
                data1_aligned = data1[data1['time_index'].isin(common_idx)].sort_values('time_index')
                data2_aligned = data2[data2['time_index'].isin(common_idx)].sort_values('time_index')
                
                if len(data1_aligned) != len(data2_aligned):
                    continue
                
                try:
                    dm_stat, p_val = diebold_mariano_test(
                        data1_aligned['y_true'].values,
                        data1_aligned['y_pred'].values,
                        data2_aligned['y_pred'].values
                    )
                    
                    result_dict = dict(zip(group_by_cols, group_vals if isinstance(group_vals, tuple) else [group_vals]))
                    result_dict.update({
                        'model1': model1,
                        'model2': model2,
                        'dm_stat': float(dm_stat),
                        'p_value': float(p_val),
                        'n_obs': len(data1_aligned)
                    })
                    dm_results.append(result_dict)
                except Exception as e:
                    print(f"Error in DM test for {model1} vs {model2}: {e}")
                    continue
    
    return pd.DataFrame(dm_results)

# ------------------------------------------------
# 9. Training & Evaluation Helpers
# ------------------------------------------------
def grid_search_model(X_train,y_train,X_val,y_val,model_type):
    best_cfg,best_loss=None,np.inf
    for cfg in ParameterGrid(param_grid[model_type]):
        m=build_model(model_type,X_train.shape[1:],layers=cfg['layers'],lr=cfg['learning_rate'])
        hist=m.fit(X_train,y_train,epochs=50,batch_size=cfg['batch_size'],
                   validation_data=(X_val,y_val),verbose=0,
                   callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)])
        val_loss=min(hist.history['val_loss'])
        if val_loss<best_loss: best_loss,best_cfg=val_loss,cfg
    return best_cfg,best_loss

def train_and_evaluate_with_preds(idx,X,y,model_type,epochs=20,batch_size=64):
    split=int(len(X)*0.8)
    X_tr,y_tr,X_te,y_te= X[:split],y[:split],X[split:],y[split:]
    idx_te=idx[split:]
    # Optional grid search for ANN
    if model_type=='ANN':
        cfg,_=grid_search_model(X_tr,y_tr,X_te,y_te,'ANN')
        model=build_model('ANN',X_tr.shape[1:],layers=cfg['layers'],lr=cfg['learning_rate'])
        batch_size=cfg['batch_size']
    else:
        model=build_model(model_type,X_tr.shape[1:])
    history=model.fit(X_tr,y_tr,epochs=epochs,batch_size=batch_size,
                      verbose=0,validation_split=0.2,
                      callbacks=[tf.keras.callbacks.EarlyStopping(patience=10)])
    y_pred=model.predict(X_te).flatten()
    mets=calculate_metrics(y_te,y_pred)
    mets['train_loss']=history.history['loss'][-1]
    mets['val_loss']=history.history['val_loss'][-1] if 'val_loss' in history.history else np.nan
    # Plots
    plt.figure();plt.plot(idx_te,y_te,label='True');plt.plot(idx_te,y_pred,label='Pred')
    plt.legend();plt.title(f'{model_type} Forecast vs True');plt.savefig(f'plots/{model_type}_forecast.png');plt.close()
    errs=y_te-y_pred;plt.figure();sns.histplot(errs,kde=True);plt.title(f'{model_type} Error Dist');plt.savefig(f'plots/{model_type}_error.png');plt.close()
    # LR & loss
    lrs=history.history.get('lr',[])
    if lrs:
        plt.figure();plt.plot(lrs);plt.title(f'{model_type} LR Schedule');plt.savefig(f'plots/{model_type}_lr.png');plt.close()
    plt.figure();plt.plot(history.history['loss'],label='train');plt.plot(history.history['val_loss'],label='val')
    plt.legend();plt.title(f'{model_type} Loss Curve');plt.savefig(f'plots/{model_type}_loss.png');plt.close()
    pred_df=pd.DataFrame({'time_index':idx_te,'y_true':y_te,'y_pred':y_pred})
    return mets,pred_df

# ------------------------------------------------
# 10. Benchmark & DM
# ------------------------------------------------
def benchmark_all_combinations():
    base_cols=['DIX','GEX','SKEW','PUTCALLRATIO']
    models=['ARIMA','GARCH','ANN','RNN','LSTM','GRU','CNN','CNN_LSTM','CapsNet']
    all_preds=[];results=[]
    df0=load_data('merged_market_data_vix.csv')
    for r in range(1,len(base_cols)+1):
        for combo in itertools.combinations(base_cols,r):
            for fractal in ['none','hurst','wavelet']:
                df=df0.copy()
                if fractal=='hurst': df=apply_hurst(df)
                if fractal=='wavelet': df,_=apply_wavelets(df)
                feats=list(combo)+([f'HURST_PRICE'] if fractal=='hurst' else [])
                feats+= [c for c in df.columns if c.startswith('WAVELET_')] if fractal=='wavelet' else []
                df.dropna(subset=feats+['VIX'],inplace=True)
                df.reset_index(inplace=True)
                X,y,idx,_=prepare_features(df,feats,'VIX')
                if X is None: continue
                for m in models:
                    if m=='ARIMA':
                        series=df['VIX'];split=int(len(series)*0.8)
                        m_ar=train_arima_baseline(series);
                        pred=m_ar.forecast(steps=len(series)-split)
                        mets=calculate_metrics(series.iloc[split:],pred.values)
                        pred_df=pd.DataFrame({'time_index':series.index[split:],'y_true':series.iloc[split:],'y_pred':pred.values})
                    elif m=='GARCH':
                        series=df['VIX'];split=int(len(series)*0.8)
                        m_g=train_garch_baseline(series)
                        # 1-step forecast variance -> vol
                        fore=m_g.forecast(horizon=len(series)-split, reindex=False)
                        vol_pred=np.sqrt(fore.variance.values[-1])
                        mets=calculate_metrics(series.iloc[split:],vol_pred)
                        pred_df=pd.DataFrame({'time_index':series.index[split:],'y_true':series.iloc[split:],'y_pred':vol_pred})
                    else:
                        mets,pd_df=train_and_evaluate_with_preds(idx,X,y,m)
                        pred_df=pd_df
                    results.append({'features':'+'.join(combo),'model':m,'fractal':fractal,**mets})
                    pred_df = pred_df.assign(features='+'.join(combo),model=m,fractal=fractal)
                    all_preds.extend(pred_df.to_dict('records'))
    pd.DataFrame(results).to_csv('results\combo_results.csv',index=False)
    all_preds_df = pd.DataFrame(all_preds)
    dm_df = compare_models_dm(all_preds_df, ['features','fractal'])
    dm_df.to_csv('results\dm_results.csv',index=False)

if __name__=='__main__': 
    benchmark_all_combinations() 
    gc.collect()
# Out:
# Requirement already satisfied: arch in c:\users\antonio-jose.martine\ai-test\lib\site-packages (7.2.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.22.3 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from arch) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from arch) (1.14.1)
# Requirement already satisfied: pandas>=1.4 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from arch) (2.2.2)
# Requirement already satisfied: statsmodels>=0.12 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from arch) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from pandas>=1.4->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from pandas>=1.4->arch) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from pandas>=1.4->arch) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from statsmodels>=0.12->arch) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from statsmodels>=0.12->arch) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\antonio-jose.martine\ai-test\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4->arch) (1.16.0)
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 5)
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 5)
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 5)
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 5)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 5)
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 5)
# Construyendo CapsNet: input_shape=(10, 5), dim_capsule=16, num_caps=10, rutings=3
# WARNING:tensorflow:From c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ✅ ARIMA | ['DIX'] + none => RMSE=3.4393, R2=0.3624
# ✅ GARCH | ['DIX'] + none => RMSE=536.3863, R2=-15506.7327
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ ANN | ['DIX'] + none => RMSE=0.0950, R2=-1.0436
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ✅ RNN | ['DIX'] + none => RMSE=0.0984, R2=-1.1069
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ✅ LSTM | ['DIX'] + none => RMSE=0.0960, R2=-1.0046
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# ✅ GRU | ['DIX'] + none => RMSE=0.0965, R2=-1.0026
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CNN | ['DIX'] + none => RMSE=0.0931, R2=-0.8772
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# ✅ CNN_LSTM | ['DIX'] + none => RMSE=0.0969, R2=-1.1592
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ CapsNet | ['DIX'] + none => RMSE=0.0955, R2=-1.1141
# ✅ ARIMA | ['DIX'] + hurst => RMSE=3.4764, R2=0.0941
# ✅ GARCH | ['DIX'] + hurst => RMSE=368.5420, R2=-10180.5441
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['DIX'] + hurst => RMSE=0.1020, R2=-1.3686
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ✅ RNN | ['DIX'] + hurst => RMSE=0.0975, R2=-1.3066
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# ✅ LSTM | ['DIX'] + hurst => RMSE=0.1016, R2=-1.3869
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# ✅ GRU | ['DIX'] + hurst => RMSE=0.0976, R2=-1.0023
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CNN | ['DIX'] + hurst => RMSE=0.0973, R2=-1.2021
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ✅ CNN_LSTM | ['DIX'] + hurst => RMSE=0.0939, R2=-0.8090
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CapsNet | ['DIX'] + hurst => RMSE=0.1021, R2=-1.4446
# ✅ ARIMA | ['DIX'] + wavelet => RMSE=3.5623, R2=-0.0203
# ✅ GARCH | ['DIX'] + wavelet => RMSE=320.2848, R2=-8246.6514
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['DIX'] + wavelet => RMSE=0.1035, R2=-2.9255
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ✅ RNN | ['DIX'] + wavelet => RMSE=0.1272, R2=-2.1857
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ LSTM | ['DIX'] + wavelet => RMSE=0.0861, R2=-0.6830
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✅ GRU | ['DIX'] + wavelet => RMSE=0.0890, R2=-0.8273
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CNN | ['DIX'] + wavelet => RMSE=0.0969, R2=-1.7664
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# ✅ CNN_LSTM | ['DIX'] + wavelet => RMSE=0.1221, R2=-3.3533
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CapsNet | ['DIX'] + wavelet => RMSE=0.0958, R2=-1.8308
# ✅ ARIMA | ['GEX'] + none => RMSE=3.4393, R2=0.3624
# ✅ GARCH | ['GEX'] + none => RMSE=536.3863, R2=-15506.7327
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ ANN | ['GEX'] + none => RMSE=0.0800, R2=-0.0494
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ RNN | ['GEX'] + none => RMSE=0.0906, R2=-0.4043
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ✅ LSTM | ['GEX'] + none => RMSE=0.0937, R2=-0.5353
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step
# ✅ GRU | ['GEX'] + none => RMSE=0.0907, R2=-0.4109
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✅ CNN | ['GEX'] + none => RMSE=0.0901, R2=-0.4192
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ CNN_LSTM | ['GEX'] + none => RMSE=0.0906, R2=-0.4031
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CapsNet | ['GEX'] + none => RMSE=0.0892, R2=-0.4024
# ✅ ARIMA | ['GEX'] + hurst => RMSE=3.4764, R2=0.0941
# ✅ GARCH | ['GEX'] + hurst => RMSE=368.5420, R2=-10180.5441
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['GEX'] + hurst => RMSE=0.0902, R2=-0.4529
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ✅ RNN | ['GEX'] + hurst => RMSE=0.0993, R2=-1.0218
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✅ LSTM | ['GEX'] + hurst => RMSE=0.0954, R2=-0.6140
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✅ GRU | ['GEX'] + hurst => RMSE=0.0962, R2=-0.6860
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CNN | ['GEX'] + hurst => RMSE=0.0898, R2=-0.4794
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# ✅ CNN_LSTM | ['GEX'] + hurst => RMSE=0.0933, R2=-0.5475
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CapsNet | ['GEX'] + hurst => RMSE=0.0918, R2=-0.5330
# ✅ ARIMA | ['GEX'] + wavelet => RMSE=3.5623, R2=-0.0203
# ✅ GARCH | ['GEX'] + wavelet => RMSE=320.2848, R2=-8246.6514
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ ANN | ['GEX'] + wavelet => RMSE=0.1099, R2=-4.2238
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# ✅ RNN | ['GEX'] + wavelet => RMSE=0.0958, R2=-1.4399
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# ✅ LSTM | ['GEX'] + wavelet => RMSE=0.0899, R2=-0.9682
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ GRU | ['GEX'] + wavelet => RMSE=0.1155, R2=-3.4117
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CNN | ['GEX'] + wavelet => RMSE=0.1320, R2=-5.7469
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ✅ CNN_LSTM | ['GEX'] + wavelet => RMSE=0.1030, R2=-1.4431
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CapsNet | ['GEX'] + wavelet => RMSE=0.1031, R2=-2.8043
# ✅ ARIMA | ['SKEW'] + none => RMSE=3.4393, R2=0.3624
# ✅ GARCH | ['SKEW'] + none => RMSE=536.3863, R2=-15506.7327
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['SKEW'] + none => RMSE=0.0968, R2=-0.6610
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ RNN | ['SKEW'] + none => RMSE=0.0975, R2=-0.9583
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# ✅ LSTM | ['SKEW'] + none => RMSE=0.0961, R2=-0.6305
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✅ GRU | ['SKEW'] + none => RMSE=0.0984, R2=-0.7329
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ✅ CNN | ['SKEW'] + none => RMSE=0.0964, R2=-0.6382
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ✅ CNN_LSTM | ['SKEW'] + none => RMSE=0.0951, R2=-0.5931
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CapsNet | ['SKEW'] + none => RMSE=0.1006, R2=-0.8156
# ✅ ARIMA | ['SKEW'] + hurst => RMSE=3.4764, R2=0.0941
# ✅ GARCH | ['SKEW'] + hurst => RMSE=368.5420, R2=-10180.5441
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ ANN | ['SKEW'] + hurst => RMSE=0.1036, R2=-1.2666
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# ✅ RNN | ['SKEW'] + hurst => RMSE=0.1022, R2=-1.0550
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ✅ LSTM | ['SKEW'] + hurst => RMSE=0.0975, R2=-0.6687
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# ✅ GRU | ['SKEW'] + hurst => RMSE=0.0917, R2=-0.5167
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✅ CNN | ['SKEW'] + hurst => RMSE=0.0983, R2=-0.8070
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# ✅ CNN_LSTM | ['SKEW'] + hurst => RMSE=0.1001, R2=-1.0673
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CapsNet | ['SKEW'] + hurst => RMSE=0.1074, R2=-1.4414
# ✅ ARIMA | ['SKEW'] + wavelet => RMSE=3.5623, R2=-0.0203
# ✅ GARCH | ['SKEW'] + wavelet => RMSE=320.2848, R2=-8246.6514
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ ANN | ['SKEW'] + wavelet => RMSE=0.1151, R2=-4.5874
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ✅ RNN | ['SKEW'] + wavelet => RMSE=0.1268, R2=-3.5442
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ✅ LSTM | ['SKEW'] + wavelet => RMSE=0.0978, R2=-1.2762
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ GRU | ['SKEW'] + wavelet => RMSE=0.0852, R2=-0.4584
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✅ CNN | ['SKEW'] + wavelet => RMSE=0.1118, R2=-2.3235
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 9)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# ✅ CNN_LSTM | ['SKEW'] + wavelet => RMSE=0.1120, R2=-2.3768
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 9), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CapsNet | ['SKEW'] + wavelet => RMSE=0.0968, R2=-1.7369
# ✅ ARIMA | ['PUTCALLRATIO'] + none => RMSE=3.4393, R2=0.3624
# ✅ GARCH | ['PUTCALLRATIO'] + none => RMSE=536.3863, R2=-15506.7327
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ ANN | ['PUTCALLRATIO'] + none => RMSE=0.0874, R2=-0.3573
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ✅ RNN | ['PUTCALLRATIO'] + none => RMSE=0.0851, R2=-0.2157
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ LSTM | ['PUTCALLRATIO'] + none => RMSE=0.0893, R2=-0.3941
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# ✅ GRU | ['PUTCALLRATIO'] + none => RMSE=0.0932, R2=-0.6199
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CNN | ['PUTCALLRATIO'] + none => RMSE=0.0879, R2=-0.3558
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 1)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ✅ CNN_LSTM | ['PUTCALLRATIO'] + none => RMSE=0.0895, R2=-0.3867
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 1), dim_capsule=16, num_caps=10, rutings=3
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CapsNet | ['PUTCALLRATIO'] + none => RMSE=0.0898, R2=-0.4643
# ✅ ARIMA | ['PUTCALLRATIO'] + hurst => RMSE=3.4764, R2=0.0941
# ✅ GARCH | ['PUTCALLRATIO'] + hurst => RMSE=368.5420, R2=-10180.5441
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['PUTCALLRATIO'] + hurst => RMSE=0.0975, R2=-1.2000
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# ✅ RNN | ['PUTCALLRATIO'] + hurst => RMSE=0.0905, R2=-0.4760
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# ✅ LSTM | ['PUTCALLRATIO'] + hurst => RMSE=0.0891, R2=-0.4496
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# ✅ GRU | ['PUTCALLRATIO'] + hurst => RMSE=0.0920, R2=-0.5662
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ✅ CNN | ['PUTCALLRATIO'] + hurst => RMSE=0.0909, R2=-0.4913
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 2)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# ✅ CNN_LSTM | ['PUTCALLRATIO'] + hurst => RMSE=0.0940, R2=-0.6582
# Construyendo CapsNet: input_shape=(10, 2), dim_capsule=16, num_caps=10, rutings=3
# ...
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ✅ RNN | ['GEX', 'SKEW'] + hurst => RMSE=0.0834, R2=-0.3447
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# ✅ LSTM | ['GEX', 'SKEW'] + hurst => RMSE=0.0984, R2=-0.7421
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ GRU | ['GEX', 'SKEW'] + hurst => RMSE=0.1023, R2=-1.1256
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✅ CNN | ['GEX', 'SKEW'] + hurst => RMSE=0.0942, R2=-0.5833
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ✅ CNN_LSTM | ['GEX', 'SKEW'] + hurst => RMSE=0.0956, R2=-0.7981
# Construyendo CapsNet: input_shape=(10, 3), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 3), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 3), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 3), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 3), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CapsNet | ['GEX', 'SKEW'] + hurst => RMSE=0.0902, R2=-0.4498
# ✅ ARIMA | ['GEX', 'SKEW'] + wavelet => RMSE=3.5623, R2=-0.0203
# ✅ GARCH | ['GEX', 'SKEW'] + wavelet => RMSE=320.2848, R2=-8246.6514
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['GEX', 'SKEW'] + wavelet => RMSE=0.0998, R2=-3.1670
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ RNN | ['GEX', 'SKEW'] + wavelet => RMSE=0.0998, R2=-2.1305
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo LSTM: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ✅ LSTM | ['GEX', 'SKEW'] + wavelet => RMSE=0.0921, R2=-1.3584
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Construyendo GRU: 2 capas [128, 64], input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# ✅ GRU | ['GEX', 'SKEW'] + wavelet => RMSE=0.1177, R2=-1.6699
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CNN: Conv1D(128)-Conv1D(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ✅ CNN | ['GEX', 'SKEW'] + wavelet => RMSE=0.0877, R2=-0.9821
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Construyendo CNN-LSTM: Conv1D(64)-LSTM(128)-LSTM(64), input_shape=(10, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ✅ CNN_LSTM | ['GEX', 'SKEW'] + wavelet => RMSE=0.0956, R2=-1.6456
# Construyendo CapsNet: input_shape=(10, 10), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo CapsNet: input_shape=(10, 10), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 10), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Construyendo CapsNet: input_shape=(10, 10), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo CapsNet: input_shape=(10, 10), dim_capsule=16, num_caps=10, rutings=3
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# ✅ CapsNet | ['GEX', 'SKEW'] + wavelet => RMSE=0.0914, R2=-1.5179
# ✅ ARIMA | ['GEX', 'PUTCALLRATIO'] + none => RMSE=3.4393, R2=0.3624
# ✅ GARCH | ['GEX', 'PUTCALLRATIO'] + none => RMSE=536.3863, R2=-15506.7327
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Construyendo ANN: 3 capas densas [128, 64, 32], input_shape=(10, 2)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ ANN | ['GEX', 'PUTCALLRATIO'] + none => RMSE=0.0819, R2=-0.1599
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Construyendo SimpleRNN: 2 capas [128, 64], input_shape=(10, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 672
#     669     print("✅ Todos los análisis completados y resultados guardados")
#     671 if __name__ == '__main__':
# --> 672     benchmark_all_combinations()
#     673     gc.collect()
#
# Cell In[4], line 627, in benchmark_all_combinations()
#     617         all_predictions.append({
#     618             'date': datex,
#     619             'features': '+'.join(combo_list),
#    (...)
#     623             'y_pred': y_pred[i] if m == 'ARIMA' else y_pred[i]
#     624         })
#     625 else:
#     626     # Modelos de deep learning con CV
# --> 627     metrics, pred_df = train_with_cv(
#     628         X, y, m, time_index, n_splits=5
#     629     )
#     631     # Guardar predicciones
#     632     pred_df['features'] = '+'.join(combo_list)
#
# Cell In[4], line 430, in train_with_cv(X, y, model_type, time_index, n_splits, epochs, batch_size)
#     427 # Callback para early stopping
#     428 early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# --> 430 history = model.fit(
#     431     X_train, y_train,
#     432     epochs=epochs,
#     433     batch_size=batch_size,
#     434     validation_split=0.2,
#     435     callbacks=[early_stop],
#     436     verbose=0
#     437 )
#     439 y_pred = model.predict(X_test).flatten()
#     440 metrics = calculate_metrics(y_test, y_pred)
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     logs = self._pythonify_logs(logs)
#     322     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\Users\antonio-jose.martine\ai-test\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
